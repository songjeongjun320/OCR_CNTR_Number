# %%
import cv2
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
# img_ori = cv2.imread('Samples_HQ\\BEAU5166075-1.jpg')
img_ori = cv2.imread('NAV_Noon_Samples\\SEGU5222859.jpg')
plt.figure(figsize=(12, 10))
plt.imshow(img_ori, cmap='gray')

# %%
img_cutted = img_ori[0:, 0:]
400
600
1500
1850
plt.imshow(img_cutted, cmap='gray')
